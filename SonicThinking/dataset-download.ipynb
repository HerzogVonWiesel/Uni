# %%
# %pip install -U simple_image_download
# Out:
# ...
#   Using cached simple_image_download-0.5-py3-none-any.whl (7.0 kB)
# ...
#   Attempting uninstall: simple_image_download
#     Found existing installation: simple-image-download 0.4
#     Uninstalling simple-image-download-0.4:
#       Successfully uninstalled simple-image-download-0.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-magic-bin==0.4.14
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from simple_image_download import simple_image_download as simp
keywords = ["hug photo", "holding hands photo", "kissing photo"]
response = simp.Downloader

for keyword in keywords:
    response().download(keyword, 300)
    print("Downloaded images for", keyword)
# Out:
# [========================================================================] 100%
# [                                                                        ]   0%
# Downloaded images for hug photo
# [========================================================================] 100%
# [                                                                        ]   0%
# Downloaded images for holding hands photo
# [========================================================================] 100%
# Downloaded images for kissing photo

# %%
# %pip install bing-image-downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader

# Keywords to search
keywords = ["person photo"]

# Function to download images
def download_images(keywords, limit=100, output_dir='downloads'):
    for keyword in keywords:
        downloader.download(keyword, limit=limit, output_dir=output_dir, adult_filter_off=True, force_replace=False, timeout=60)
        print(f"Downloaded images for keyword: {keyword}")

# Download images for each keyword
download_images(keywords)
# Out:
# [%] Downloading Images to c:\Uni_Master\SonicThinking\downloads\two persons photo
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://st.focusedcollection.com/8860618/i/1800/focused_124364670-stock-photo-two-people-talking.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.mychildmagazine.com.au/wp-content/uploads/2016/01/2-people-1-relationship-01-1024x857.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/b/two-business-persons-2218402.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://dm0qx8t0i9gc9.cloudfront.net/thumbnails/video/NDcUKEpwx/the-meeting-of-two-business-people_sq8kiegr_thumbnail-1080_01.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://thumbs.dreamstime.com/z/two-persons-795473.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://thumbs.dreamstime.com/z/two-persons-3647652.jpg
# ...
